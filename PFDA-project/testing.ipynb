# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from util import *

# %%
df = pd.read_excel('/workspaces/PFDA/System-Data-Qtr-Hourly-November-2024 (1).xlsx')
df.head()
# Out:
#              DateTime  GMT Offset  NI Generation  NI Demand  \
# 0 2024-01-01 00:00:00           0        715.613    584.635
# 1 2024-01-01 00:15:00           0        702.913    570.701
# 2 2024-01-01 00:30:00           0        799.801    563.575
# 3 2024-01-01 00:45:00           0        877.653    562.830
# 4 2024-01-01 01:00:00           0        872.636    577.349
#
#    NI Wind Availability  NI Wind Generation  NI Solar Availability  \
# 0               541.716             249.907                    0.0
# 1               528.684             216.946                    0.0
# 2               506.628             301.445                    0.0
# 3               512.047             376.547                    0.0
# 4               501.778             378.713                    0.0
#
#    NI Solar Generation  Moyle I/C  NI Wind Penetration  ...  AI Hydro  \
# 0                  0.0    189.187             0.427458  ...    179.15
# 1                  0.0    159.985             0.380140  ...    178.21
# 2                  0.0     84.050             0.534880  ...    177.41
# 3                  0.0     25.885             0.669024  ...    177.37
# 4                  0.0     80.209             0.655952  ...    177.72
#
#    Inter-Jurisdictional Flow  AI Wind Penetration  AI Solar Penetration  \
# 0                    -308.06             0.616345              0.000025
# 1                    -279.58             0.605382              0.000025
# 2                    -306.58             0.630409              0.000025
# 3                    -326.14             0.646677              0.000023
# 4                    -363.06             0.636304              0.000026
#
#    AI Oversupply  AI Oversupply Percentage    SNSP  Unnamed: 34  Unnamed: 35  \
# 0            0.0                       0.0  0.6632          NaN          NaN
# 1            0.0                       0.0  0.6442          NaN          NaN
# 2            0.0                       0.0  0.6327          NaN          NaN
# 3            0.0                       0.0  0.6277          NaN          NaN
# 4            0.0                       0.0  0.6316          NaN          NaN
#
#    NI: Northern Ireland \nIE: Ireland \nAI: All Island
# 0  Notes: \nThe system data in this report is is ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['DateTime', 'GMT Offset', 'NI Generation', 'NI Demand',
#        'NI Wind Availability', 'NI Wind Generation', 'NI Solar Availability',
#        'NI Solar Generation', 'Moyle I/C', 'NI Wind Penetration',
#        'NI Solar Penetration', 'IE Generation', 'IE Demand',
#        'IE Wind Availability', 'IE Wind Generation', 'IE Solar Availability',
#        'IE Solar Generation', 'IE Hydro', 'EWIC I/C', 'IE Wind Penetration',
#        'IE Solar Penetration', 'AI Generation', 'AI Demand',
#        'AI Wind Availability', 'AI Wind Generation', 'AI Solar Availability',
#        'AI Solar Generation', 'AI Hydro', 'Inter-Jurisdictional Flow',
#        'AI Wind Penetration', 'AI Solar Penetration', 'AI Oversupply',
#        'AI Oversupply Percentage', 'SNSP', 'Unnamed: 34', 'Unnamed: 35',
#        'NI: Northern Ireland \nIE: Ireland \nAI: All Island '],
#       dtype='object')

# %%
# Extract the location from the csv files in weather
csv_files = glob.glob('data/weather/*.csv')

location = []

for file in csv_files:
    name = extract_location(file)
    location.append(name)
print(location)

# %%
# Extract the location from the csv files in weather
csv_files = glob.glob('data/weather/*.csv')

location_dict = {}

for file in csv_files:
    name = extract_location(file)
    location_dict[name + '_df'] = file
print(location_dict)

# %%
def load_weather(file_name):
    '''A function to read in a weather csv file.'''
       
    file_path = 'data/weather/'

    for skip_rows in [17, 23]:
        weather_df = pd.read_csv(file_path + file_name,
            skiprows = skip_rows,
            usecols= ['date', 'rain', 'temp', 'msl', 'wdsp', 'wddir'],
            na_values = ' ',
            index_col= 'date', 
            parse_dates= ['date'], 
            date_format = "%d-%b-%Y %H:%M")
            
        weather_df = weather_df['2014': '2024']

    return weather_df

#date, rain,temp,msl,wdsp,wddir
